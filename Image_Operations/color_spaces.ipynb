# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from typing import Any

# %%
def imshow(title: str, image: Any, size: int = 5):
    w, h = image.shape[0], image.shape[1]
    aspect_ratio = w / h
    plt.figure(figsize=(size * aspect_ratio, size))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()


image = cv2.imread("../img/аватарка.jpg")

# %% [markdown]
# Using cv2.split

# %%
B, G, R = cv2.split(image)

print(B.shape)
print(G.shape)
print(R.shape)
# Out:
# (460, 460)
# (460, 460)
# (460, 460)

# %%
zeros = np.zeros(image.shape[:2], dtype="uint8")

imshow("Red", cv2.merge([zeros, zeros, R]))
imshow("Green", cv2.merge([zeros, G, zeros]))
imshow("Blue", cv2.merge([B, zeros, zeros]))

# %%
imshow("Original", cv2.merge([B, G, R]))

# %%
imshow("Original", cv2.merge([B+15, G+25, R+10]))

# %% [markdown]
# HSV

# %%
hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

imshow("HSV", hsv_image)

# %%
imshow("Hue", hsv_image[:, :, 0])
imshow("Saturation", hsv_image[:, :, 1])
imshow("Value", hsv_image[:, :, 2])
